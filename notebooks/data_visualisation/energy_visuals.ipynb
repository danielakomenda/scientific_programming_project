# %%
import pandas as pd
import matplotlib.pyplot as plt

import sp_project.data_preparation.db_entsoe
# Out:
# ---------------------------------------------------------------------------
# NoNameservers                             Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pymongo/srv_resolver.py:89, in _SrvResolver._resolve_uri(self, encapsulate_errors)
#      88 try:
# ---> 89     results = _resolve(
#      90         "_" + self.__srv + "._tcp." + self.__fqdn, "SRV", lifetime=self.__connect_timeout
#      91     )
#      92 except Exception as exc:
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/pymongo/srv_resolver.py:43, in _resolve(*args, **kwargs)
#      41 if hasattr(resolver, "resolve"):
#      42     # dnspython >= 2
# ---> 43     return resolver.resolve(*args, **kwargs)
#      44 # dnspython 1.X
#
# File ~/.pyenv/versions/3.10.4/lib/python3.10/site-packages/dns/resolver.py:1368, in resolve(qname, rdtype, rdclass, tcp, source, raise_on_no_answer, source_port, lifetime, search)
# ...
